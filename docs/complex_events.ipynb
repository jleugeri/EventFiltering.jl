# %%
Mod = include("../src/EventFiltering.jl")
using Mod.EventFiltering

# %% [markdown]
# To compose more complex, repeating patterns of events, two event trains can be convolved:

# %%
F = ExponentialFilter(0.5)

e1 = EventTrain([0.0, 5.0, 10.0], [1, 2, 0.5])
e2 = 2*EventTrain([0.1, 0.2, 0.5, 0.6])
e3 = e1 ∘ (F ∘ e2)
# Out:
# EventFiltering.FilteredEventTrain{Float64,Array{Float64,1},EventFiltering.GammaFilter{Float64,Float64,Int64}}(EventFiltering.EventTrain{Float64,Array{Float64,1}}([0.1, 0.2, 0.5, 0.6, 5.1, 5.2, 5.5, 5.6, 10.1, 10.2, 10.5, 10.6], [2.0, 2.0, 2.0, 2.0, 4.0, 4.0, 4.0, 4.0, 1.0, 1.0, 1.0, 1.0]), EventFiltering.GammaFilter{Float64,Float64,Int64}(0.5, 1))

# %% [markdown]
# Let's plot the result:

# %%
using Plots
plot(e1, color=:red, linewidth=3)
plot!(e3, 0.0, 20.0, show_events=true, show_kernels=true)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip4800">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4801">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4800)" points="
# 22.3377,375.813 580.315,375.813 580.315,11.811 22.3377,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4802">
#     <rect x="22" y="11" width="559" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.3377,375.813 22.3377,11.811
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   161.832,375.813 161.832,11.811
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   301.326,375.813 301.326,11.811
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   440.821,375.813 440.821,11.811
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,375.813 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.3377,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.3377,277.083 580.315,277.083
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.3377,178.353 580.315,178.353
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.3377,79.6224 580.315,79.6224
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,375.813 22.3377,11.811
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,375.813 22.3377,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   161.832,375.813 161.832,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   301.326,375.813 301.326,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   440.821,375.813 440.821,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,375.813 30.7073,375.813
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,277.083 30.7073,277.083
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,178.353 30.7073,178.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,79.6224 30.7073,79.6224
#   "/>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 22.3377, 389.613)" x="22.3377" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 161.832, 389.613)" x="161.832" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 301.326, 389.613)" x="301.326" y="389.613">10</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 440.821, 389.613)" x="440.821" y="389.613">15</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">20</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 380.313)" x="16.3377" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 281.583)" x="16.3377" y="281.583">2</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 182.853)" x="16.3377" y="182.853">4</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 84.1224)" x="16.3377" y="84.1224">6</text>
# </g>
# <polyline clip-path="url(#clip4802)" style="stroke:#ff0000; stroke-width:3; stroke-opacity:1; fill:none" points="
#   22.3377,375.813 22.3377,326.448
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#ff0000; stroke-width:3; stroke-opacity:1; fill:none" points="
#   161.832,375.813 161.832,277.083
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#ff0000; stroke-width:3; stroke-opacity:1; fill:none" points="
#   301.326,375.813 301.326,351.131
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   25.1275,375.813 25.1275,277.083
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   27.9174,375.813 27.9174,277.083
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   36.2871,375.813 36.2871,277.083
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.077,375.813 39.077,277.083
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   164.622,375.813 164.622,178.353
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   167.412,375.813 167.412,178.353
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   175.781,375.813 175.781,178.353
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   178.571,375.813 178.571,178.353
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   304.116,375.813 304.116,326.448
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:n

# %% [markdown]
# As we can see, the pattern defined by `e2`, convolved by `F`, repeats at every point defined by `e1`.
# Notice how each event is scaled according to `e1` and `e2`!
